# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('mysql+pymysql://test:1234@localhost/itri?charset=utf8mb4')

# %%
sql = '''select * from user_record;'''

# %%
df_sql = pd.read_sql_query(sql, engine)

# %%
df = pd.read_sql_query(sql, engine)

# %%
user_email = df[df['pro_num']=='CHY-109PV0012']

# %%
user_email.iloc[0].user_email
# Out:
# 'goodderek1@itri.org.tw'

# %%
user_list = list(df[df.user_email!=''].user_email.unique())

# %%
user_list
# Out:
# ['goodderek1@itri.org.tw',
#  'itri457977@itri.org.tw',
#  'itriA80333@itri.org.tw',
#  'CMShu@itri.org.tw',
#  'chinyanghuang@itri.org.tw',
#  'emma.tsai@itri.org.tw']

# %%
df_a = df[df.assoc_name=='陳彥蓉']

# %%
df_a
# Out:
#             pro_num              user_email assoc_name  \
# 725       108PV0562  itri457977@itri.org.tw        陳彥蓉
# 726       108PV0563  itri457977@itri.org.tw        陳彥蓉
# 823       108PV0662  itri457977@itri.org.tw        陳彥蓉
# 834       108PV0673  itri457977@itri.org.tw        陳彥蓉
# 835       108PV0674  itri457977@itri.org.tw        陳彥蓉
# 1365      108PV1236  itri457977@itri.org.tw        陳彥蓉
# 1368      108PV1239  itri457977@itri.org.tw        陳彥蓉
# 1370      108PV1241  itri457977@itri.org.tw        陳彥蓉
# 1385      108PV1257  itri457977@itri.org.tw        陳彥蓉
# 1659      108PV1537  itri457977@itri.org.tw        陳彥蓉
# 1830      108PV1712  itri457977@itri.org.tw        陳彥蓉
# 2032      108PV1917  itri457977@itri.org.tw        陳彥蓉
# 2535      109PV0018  itri457977@itri.org.tw        陳彥蓉
# 3669  KHH-108PV0361  itri457977@itri.org.tw        陳彥蓉
# 4386  KHH-109PV0006  itri457977@itri.org.tw        陳彥蓉
# 6143  PCH-109PV0270  itri457977@itri.org.tw        陳彥蓉
# 6730  TNN-108PV0520  itri457977@itri.org.tw        陳彥蓉
# 6984  TNN-108PV0781  itri457977@itri.org.tw        陳彥蓉
# 7021  TNN-108PV0819  itri457977@itri.org.tw        陳彥蓉
# 7050  TNN-108PV0848  itri457977@itri.org.tw        陳彥蓉
# 7106  TNN-108PV0904  itri457977@itri.org.tw        陳彥蓉
# 7127  TNN-108PV0925  itri457977@itri.org.tw        陳彥蓉
# 7129  TNN-108PV0927  itri457977@itri.org.tw        陳彥蓉
# 7131  TNN-108PV0929  itri457977@itri.org.tw        陳彥蓉
# 7468  TNN-109PV0281  itri457977@itri.org.tw        陳彥蓉
# 7469  TNN-109PV0282  itri457977@itri.org.tw        陳彥蓉
# 7470  TNN-109PV0283  itri457977@itri.org.tw        陳彥蓉
# 7471  TNN-109PV0284  itri457977@itri.org.tw        陳彥蓉
# 8256  TXG-108PV0520  itri457977@itri.org.tw        陳彥蓉
# 9024  TYU-108PV0308  itri457977@itri.org.tw        陳彥蓉
# 9134  TYU-109PV0016  itri457977@itri.org.tw        陳彥蓉
# 9172  TYU-109PV0055  itri457977@itri.org.tw        陳彥蓉
# 9228  TYU-109PV0111  itri457977@itri.org.tw        陳彥蓉
# 9836  YUN-109PV0093  itri457977@itri.org.tw        陳彥蓉
# 9856  YUN-109PV0113  itri457977@itri.org.tw        陳彥蓉
#
#                           assoc_tel
# 725
# 726
# 823
# 834
# 835
# 1365
# 1368
# 1370
# 1385
# 1659
# 1830
# 2032
# 2535
# 3669
# 4386
# 6143  02-27790311#18/03-6581956#228
# 6730
# 6984
# 7021
# 7050
# 7106
# 7127
# 7129
# 7131
# 7468                 02-27790311#22
# 7469                 02-27790311#22
# 7470                 02-27790311#22
# 7471
# 8256
# 9024
# 9134                     03-6581956
# 9172                 02-27790311#22
# 9228                 02-27790311#22
# 9836                 02-27790311#22
# 9856                 02-27790311#22

# %%
assoc_name = []
assoc_tel = []
for index in range(len(user_list)):
    assoc_name.append(list(df[df.user_email==user_list[index]].assoc_name))
    assoc_tel.append(list(df[df.user_email==user_list[index]].assoc_tel))

# %%
df_no = df[df.user_email == '']
df_with = df[df.user_email != '']

# %%
for index in range(len(user_list)):
    for i in range(len(assoc_name[index])):
        df.loc[(df['user_email']=='')&(df['assoc_name'] == assoc_name[index][i]) | (df['assoc_tel'] == assoc_tel[index][i]),'user_email'] = user_list[index]

# %%
df[df.assoc_name=='張亞菁']
# Out:
#             pro_num              user_email assoc_name        assoc_tel
# 809       108PV0294  itri457977@itri.org.tw        張亞菁  02-27915585#207
# 819       108PV0307  itri457977@itri.org.tw        張亞菁  02-27915585#207
# 821       108PV0306  itri457977@itri.org.tw        張亞菁  02-27915585#207
# 822       108PV0293  itri457977@itri.org.tw        張亞菁  02-27915585#207
# 5441      108PV1988  itri457977@itri.org.tw        張亞菁      02-27915585
# 8195  YUN-107PV0539  itri457977@itri.org.tw        張亞菁       0909419026
# 8225  YUN-107PV0457  itri457977@itri.org.tw        張亞菁       0909419026
# 8330  YUN-107PV0451  itri457977@itri.org.tw        張亞菁       0909419026
# 8344  YUN-107PV0540  itri457977@itri.org.tw        張亞菁       0909419026
# 8426  YUN-107PV0541  itri457977@itri.org.tw        張亞菁       0909419026

# %%
#df.to_sql('user_record', engine, index= False,if_exists='replace')
